# %%
import requests
import os

# %%
os.environ["HF_HUB_OFFLINE"] = "1"
# Comment this out at init if you need to run benchmarking remotely from HF-Hub

# %%
import euroeval

# %%
api_key = "glpat-1wzQZXqVtPtZ6zT8pJzx"
api_base = "https://api.helmholtz-blablador.fz-juelich.de/v1"
headers =  {
    'accept': 'application/json',
    'Authorization': f'Bearer {api_key}',
    'Content-Type': 'application/json'
}
# auth = requests.auth.HTTPBasicAuth('apikey', api_key)

# %%
response = requests.get(os.path.join(api_base, "models"), headers=headers)

# %%
response.json()

# %% [markdown]
# ## Post

# %%
body = {
    "model": "alias-reasoning",
    "messages": [{"role":"user", "content": "What is your name? answer in 3 words."}],
    "temperature": 0.7,
    "top_p": 1,
    "top_k": -1,
    "n": 1,
    "max_tokens": 1000,
    "stop": "string",
    "stream": False,
    "presence_penalty": 0,
    "frequency_penalty": 0,
    "user": "string"
}

# %%
response = requests.post(os.path.join(api_base, "chat/completions"), headers=headers, json=body)

# %%
response.json()

# %% [markdown]
# ## Implement the Benchmarker

# %%
benchmarker = euroeval.Benchmarker(api_base=api_base, api_key=api_key)

# %%
benchmarker.benchmark(model="openai/alias-fast", task="sentiment-classification")

# %%
euroeval.dataset_configs.get_all_dataset_configs()
